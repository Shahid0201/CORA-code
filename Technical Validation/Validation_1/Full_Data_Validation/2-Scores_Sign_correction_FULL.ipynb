# %%
import pandas as pd

# -----------------------------
# Load existing scores
# -----------------------------
df = pd.read_csv("Scores.csv", encoding="utf-8-sig")

# -----------------------------
# Build corrected feminine and masculine indices
# -----------------------------
df["feminine_index_corrected"] = (
    df["ppron_z"] +
    df["verb_z"] +
    df["auxverb_z"] +
    df["cogproc_z"]
    - df["negemo_z"]
    - df["anx_z"]
    - df["negate_z"]
    - df["certain_z"]
)

df["masculine_index_corrected"] = (
    df["article_z"] +
    df["preps_z"] +
    df["posemo_z"] +
    df["sixltr_z"]
)

# -----------------------------
# Save corrected file
# -----------------------------
df.to_csv("Scores_CORRECTED.csv", index=False, encoding="utf-8-sig")

print("Saved Scores_CORRECTED.csv with corrected composite indices.")
# Out:
# C:\Users\sr3987\AppData\Local\Temp\ipykernel_10540\3789540370.py:6: DtypeWarning: Columns (8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Scores.csv", encoding="utf-8-sig")
# Saved Scores_CORRECTED.csv with corrected composite indices.
